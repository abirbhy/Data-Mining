# %%
import numpy as np
import pandas as pd

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
songs_df = pd.read_csv ('./songs_train.csv')

# %%
songs_df.shape
# Out:
# (3371, 35)

# %%
y_test_final=pd.read_csv ('./songs_test_target_predictions_example.csv')

# %%
y_test_final.shape
# Out:
# (843, 1)

# %%
songs_df.head(5)
# Out:
#             singer_id singer_location_city  singer_location_lat  \
# 0  ARGMRRK1187FB5BE1F        Not available               37.157
# 1  ARHRY5S1187B99B96F              Alabama               32.614
# 2  AR77FBJ1187FB49D8D          Detroit, MI               42.332
# 3  AREB22L1187B9A4BCE        Not available               37.157
# 4  ARBB58Y1187B9B621B        Not available               37.157
#
#    singer_location_long                    singer_name  singer_rating  \
# 0               -63.933  Dean Elliott And His Big Band          0.321
# 1               -86.681                       Static-X          0.561
# 2               -83.048          The Rance Allen Group          0.314
# 3               -63.933                        Bad Azz          0.341
# 4               -63.933          Bill & Gloria Gaither          0.333
#
#    singer_reputation     singer_styles  singer_styles_nb             song_ID  \
# 0              0.420               NaN               0.0  SOCSFMW12AB01826F2
# ...

# %%
songs_df.isnull().sum()
# Out:
# singer_id                  0
# singer_location_city       0
# singer_location_lat        0
# singer_location_long       0
# singer_name                0
# singer_rating              0
# singer_reputation          0
# singer_styles           1778
# singer_styles_nb           0
# song_ID                    0
# song_ID_similar            0
# song_decibels              0
# song_genre                 0
# song_length_seconds        0
# song_metadata_01           0
# song_metadata_02           0
# song_metadata_03           0
# song_metadata_04           0
# song_metadata_05           0
# song_metadata_06           0
# song_metadata_07           0
# song_metadata_08           0
# song_metadata_09           0
# song_metadata_10           0
# song_metadata_11           0
# song_metadata_12           0
# song_metadata_13           0
# song_metadata_14           0
# song_metadata_15           0
# song_metadata_16           0
# song_rating                0
# song_release_ID            0
# ...

# %%
songs_df
# Out:
#                singer_id singer_location_city  singer_location_lat  \
# 0     ARGMRRK1187FB5BE1F        Not available               37.157
# 1     ARHRY5S1187B99B96F              Alabama               32.614
# 2     AR77FBJ1187FB49D8D          Detroit, MI               42.332
# 3     AREB22L1187B9A4BCE        Not available               37.157
# 4     ARBB58Y1187B9B621B        Not available               37.157
# ...                  ...                  ...                  ...
# 3366  ARML3X41187FB35F2E        Not available               37.157
# 3367  ARR6MOS1187B994C51           BorlA$?nge               37.157
# 3368  AR1CB5G1187B9AFB8E  Birmingham, England               52.479
# 3369  ARHNMEZ11F50C4706C            Tennessee               35.831
# 3370  ARCP94M1187B9B0F56    Buffalo, New York               42.885
#
#       singer_location_long                    singer_name  singer_rating  \
# 0                  -63.933  Dean Elliott And His Big Band          0.321
# ...

# %%
songs_df.song_year.value_counts()
# Out:
# 0       1198
# 2006     162
# 2005     162
# 2009     139
# 2007     137
# 2008     131
# 2004     129
# 2003     128
# 2002      95
# 2001      95
# 2000      91
# 1999      81
# 1998      73
# 1995      62
# 1993      53
# 1997      53
# 1994      44
# 2010      44
# 1996      42
# 1992      38
# 1991      38
# 1989      34
# 1990      32
# 1988      26
# 1986      25
# 1987      22
# 1983      20
# 1979      19
# 1980      15
# 1982      15
# 1984      14
# 1981      14
# 1971      14
# 1985      11
# 1973      11
# 1977      11
# 1972      11
# 1967      10
# 1975      10
# 1974       9
# 1969       8
# 1970       7
# 1968       7
# 1963       6
# 1978       6
# 1960       4
# 1964       4
# 1966       3
# 1976       3
# 1961       1
# 1962       1
# 1959       1
# 1954       1
# 1965       1
# Name: song_year, dtype: int64

# %%
songs_df.dtypes
# Out:
# singer_id                object
# singer_location_city     object
# singer_location_lat     float64
# singer_location_long    float64
# singer_name              object
# singer_rating           float64
# singer_reputation       float64
# singer_styles            object
# singer_styles_nb        float64
# song_ID                  object
# song_ID_similar          object
# song_decibels           float64
# song_genre               object
# song_length_seconds     float64
# song_metadata_01        float64
# song_metadata_02        float64
# song_metadata_03        float64
# song_metadata_04        float64
# song_metadata_05        float64
# song_metadata_06        float64
# song_metadata_07        float64
# song_metadata_08          int64
# song_metadata_09        float64
# song_metadata_10        float64
# song_metadata_11        float64
# song_metadata_12        float64
# song_metadata_13        float64
# song_metadata_14        float64
# song_metadata_15        float64
# ...

# %%
songs_df.head()
# Out:
#             singer_id singer_location_city  singer_location_lat  \
# 0  ARGMRRK1187FB5BE1F        Not available               37.157
# 1  ARHRY5S1187B99B96F              Alabama               32.614
# 2  AR77FBJ1187FB49D8D          Detroit, MI               42.332
# 3  AREB22L1187B9A4BCE        Not available               37.157
# 4  ARBB58Y1187B9B621B        Not available               37.157
#
#    singer_location_long                    singer_name  singer_rating  \
# 0               -63.933  Dean Elliott And His Big Band          0.321
# 1               -86.681                       Static-X          0.561
# 2               -83.048          The Rance Allen Group          0.314
# 3               -63.933                        Bad Azz          0.341
# 4               -63.933          Bill & Gloria Gaither          0.333
#
#    singer_reputation     singer_styles  singer_styles_nb             song_ID  \
# 0              0.420               NaN               0.0  SOCSFMW12AB01826F2
# ...

# %%
songs_df.song_metadata_15.value_counts()
# Out:
# 4.0    2228
# 1.0     448
# 3.0     406
# 5.0     192
# 7.0      95
# 0.0       2
# Name: song_metadata_15, dtype: int64

# %%
songs_df.song_metadata_08.value_counts()
# Out:
# 1    2323
# 0    1048
# Name: song_metadata_08, dtype: int64

# %%
songs_df_test=songs_df[['song_metadata_08','singer_name']]

# %%
songs_df['singer_id'][1]
# Out:
# 'ARHRY5S1187B99B96F'

# %%
songs_df.singer_styles.value_counts()
# Out:
# classic pop and rock          121
# rock and indie                 99
# hip hop rnb and dance hall     78
# uk                             77
# british                        68
#                              ...
# mexican                         1
# latin jazz                      1
# roots rock                      1
# doom metal                      1
# comedy                          1
# Name: singer_styles, Length: 212, dtype: int64

# %%
songs_df.singer_styles_nb.value_counts()
# Out:
# 0.0    1778
# 1.0    1168
# 2.0     264
# 3.0      82
# 4.0      45
# 5.0      26
# 6.0       7
# 9.0       1
# Name: singer_styles_nb, dtype: int64

# %%
songs_df.singer_location_city.value_counts()
# Out:
# Not available                1218
# London, England                68
# Los Angeles, CA                68
# New York, NY                   55
# California - LA                29
#                              ...
# Bridgend, South Wales, UK       1
# Lexington, KY                   1
# Cotton Plant, AR                1
# Fort Wayne, Indiana             1
# Bolton, MS                      1
# Name: singer_location_city, Length: 688, dtype: int64

# %%
songs_df.song_genre.value_counts()
# Out:
# blues-rock      164
# hip hop         126
# ccm              82
# post-grunge      71
# country rock     58
#                ...
# disco house       1
# banda             1
# jug band          1
# zouklove          1
# early music       1
# Name: song_genre, Length: 346, dtype: int64

# %%
songs_df_sub = songs_df.drop(columns=['singer_id', 'song_ID','singer_location_city','singer_location_lat', 'singer_location_long', 'song_release_ID',"song_release_name","song_title",'singer_name','singer_styles','singer_styles_nb','song_ID_similar','song_genre'], axis=1).reset_index(drop=True)

# %%
songs_df_sub.shape
# Out:
# (3371, 22)

# %%
songs_df_sub.head()
# Out:
#    singer_rating  singer_reputation  song_decibels  song_length_seconds  \
# 0          0.321              0.420        -10.727              150.334
# 1          0.561              0.768         -3.294              189.100
# 2          0.314              0.488         -4.152              337.162
# 3          0.341              0.552         -5.345              237.792
# 4          0.333              0.427        -14.492              290.063
#
#    song_metadata_01  song_metadata_02  song_metadata_03  song_metadata_04  \
# 0             0.001             0.558             0.957             0.084
# 1             0.320             1.560             0.000             0.557
# 2             0.024             0.859             1.000             0.302
# 3             0.197             0.257             0.904             0.257
# 4             0.461             1.253             0.599             0.451
#
#    song_metadata_05  song_metadata_06  ...  song_metadata_09  \
# ...

# %%
X=songs_df_sub.drop(columns='song_rating',axis=1)
Y=songs_df_sub.song_rating

# %%
X.shape
# Out:
# (3371, 21)

# %%
Y.shape
# Out:
# (3371,)

# %%
X.dtypes
# Out:
# singer_rating          float64
# singer_reputation      float64
# song_decibels          float64
# song_length_seconds    float64
# song_metadata_01       float64
# song_metadata_02       float64
# song_metadata_03       float64
# song_metadata_04       float64
# song_metadata_05       float64
# song_metadata_06       float64
# song_metadata_07       float64
# song_metadata_08         int64
# song_metadata_09       float64
# song_metadata_10       float64
# song_metadata_11       float64
# song_metadata_12       float64
# song_metadata_13       float64
# song_metadata_14       float64
# song_metadata_15       float64
# song_metadata_16       float64
# song_year                int64
# dtype: object

# %%
Y.dtypes
# Out:
# dtype('float64')

# %% [markdown]
# # Model builing

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor, GradientBoostingRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, log_loss
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3)

# %%
classifiers=[KNeighborsRegressor(),LinearRegression(),RandomForestRegressor(),AdaBoostRegressor(),GradientBoostingRegressor()]

# %%
results_list = []
for clf in classifiers:
    clf_name = clf.__class__.__name__
    print("="*30)
    print(clf_name)
    clf.fit(X_train, y_train)
        
    test_predictions = clf.predict(X_test)
    results_list.append(mean_absolute_error(test_predictions, y_test))
# Out:
# ...
# KNeighborsRegressor
# ...
# LinearRegression
# ...
# RandomForestRegressor
# /home/ilyes/.conda/envs/tensorflow-gpu/lib/python3.6/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# ...
# AdaBoostRegressor
# ...
# GradientBoostingRegressor

# %%
for a in results_list:
    print(a)
# Out:
# 0.13324209486166008
# 0.11016859387242195
# 0.11291068091987065
# 0.1160785805440627
# 0.10997703693966601

# %%
results_list_test = []
for clf in classifiers:
    clf_name = clf.__class__.__name__
    print("="*30)
    print(clf_name)
        
    test_predictions = clf.predict(X_test)
    results_list.append(mean_absolute_error(test_predictions, y_test))
# Out:
# ...
# XGBRegressor
# ...
# KNeighborsRegressor
# ...
# LinearRegression
# ...
# RandomForestRegressor
# ...
# AdaBoostRegressor
# ...
# GradientBoostingRegressor

# %%
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# # random forest regressor

# %%
# Create the parameter grid based on the results of random search 
param_grid = {
    'bootstrap': [True],
    'max_depth': [80, 90, 100, 110],
    'max_features': [2, 3],
    'min_samples_leaf': [3, 4, 5],
    'min_samples_split': [8, 10, 12],
    'n_estimators': [100, 200, 300, 1000]
}
# Create a based model
rf = RandomForestRegressor()
# Instantiate the grid search model
grid_search = GridSearchCV(scoring='neg_mean_absolute_error',estimator = rf, param_grid = param_grid, cv = 10, n_jobs = -1, verbose = 2)

# %%
grid_search.fit(X_train,y_train)
# Out:
# Fitting 10 folds for each of 288 candidates, totalling 2880 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:    4.1s
# [Parallel(n_jobs=-1)]: Done 146 tasks      | elapsed:   27.7s
# [Parallel(n_jobs=-1)]: Done 349 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 632 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 997 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=-1)]: Done 1442 tasks      | elapsed:  5.9min
# [Parallel(n_jobs=-1)]: Done 1969 tasks      | elapsed:  8.0min
# [Parallel(n_jobs=-1)]: Done 2576 tasks      | elapsed: 10.5min
# [Parallel(n_jobs=-1)]: Done 2880 out of 2880 | elapsed: 11.9min finished
# GridSearchCV(cv=10, error_score='raise-deprecating',
#              estimator=RandomForestRegressor(bootstrap=True, criterion='mse',
#                                              max_depth=None,
# ...

# %%
test_predictions=grid_search.predict(X_test)
print(mean_absolute_error(test_predictions, y_test))
# Out:
# 0.11183279493048211

# %%
grid_search.best_params_
# Out:
# {'bootstrap': True,
#  'max_depth': 90,
#  'max_features': 3,
#  'min_samples_leaf': 3,
#  'min_samples_split': 8,
#  'n_estimators': 300}

# %% [markdown]
# {'bootstrap': True,
#  'max_depth': 90,
#  'max_features': 3,
#  'min_samples_leaf': 3,
#  'min_samples_split': 8,
#  'n_estimators': 1000}

# %% [markdown]
# # gradientboost regressor

# %%
param_grid_gbr ={
    'learning_rate':[0.01,0.05,0.03,0.08],
    'n_estimators':[85,90,95],
    'max_depth':[3,4,5,6],
    'subsample':[0.625,0.65,0.675]
}
gbr=GradientBoostingRegressor()
grid_search_gbr = GridSearchCV(estimator = gbr, param_grid = param_grid_gbr, cv = 10, n_jobs = -1, verbose = 2)

# %%
grid_search_gbr.best_params_
# Out:
# {'learning_rate': 0.03, 'max_depth': 5, 'n_estimators': 85, 'subsample': 0.675}

# %%
grid_search_gbr.fit(X_train,y_train)
# Out:
# Fitting 10 folds for each of 144 candidates, totalling 1440 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=-1)]: Done 146 tasks      | elapsed:    7.9s
# [Parallel(n_jobs=-1)]: Done 349 tasks      | elapsed:   26.6s
# [Parallel(n_jobs=-1)]: Done 632 tasks      | elapsed:   45.4s
# [Parallel(n_jobs=-1)]: Done 997 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 1440 out of 1440 | elapsed:  1.9min finished
# GridSearchCV(cv=10, error_score='raise-deprecating',
#              estimator=GradientBoostingRegressor(alpha=0.9,
#                                                  criterion='friedman_mse',
#                                                  init=None, learning_rate=0.1,
#                                                  loss='ls', max_depth=3,
#                                                  max_features=None,
# ...

# %%
test_predictions=grid_search_gbr.predict(X_test)
print(mean_absolute_error(test_predictions, y_test))
# Out:
# 0.10916199285941584

# %%
songs_df_final = pd.read_csv ('./songs_test_without_target.csv')
songs_df_final_sub = songs_df_final.drop(columns=['singer_id', 'song_ID','singer_location_city','singer_location_lat', 'singer_location_long', 'song_release_ID',"song_release_name","song_title",'singer_name','singer_styles','singer_styles_nb','song_ID_similar','song_genre'], axis=1).reset_index(drop=True)
test_predictions_gbr_final=classifiers[4].predict(songs_df_final_sub)
df = pd.Series(test_predictions_gbr_final)
df.name = 'song_rating'
df.to_csv('./songs_test_target_predictions.csv', index=False,float_format="%.3f", header=True)
